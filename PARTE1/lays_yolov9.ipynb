# %% [markdown]
# # Detector de Papas Lays con YOLOv9

# %%
# !pip install ultralytics

# %% [markdown]
# # Entrenamiento

# %%
# !unzip -q lays.zip
import zipfile

with zipfile.ZipFile("zip.zip", 'r') as zip_ref:
    zip_ref.extractall(".")  # Extrae todo en la carpeta actual

# %%
from ultralytics import YOLO

model = YOLO('yolo12s.pt')

# %%
results = model.train(data='data.yaml', epochs=1, imgsz=416)
# Out:
# New https://pypi.org/project/ultralytics/8.3.203 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.168  Python-3.10.0 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i9-13900H)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=1, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=416, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs\detect\train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 4]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1    345856  ultralytics.nn.modules.block.A2C2f           [768, 256, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     95104  ultralytics.nn.modules.block.A2C2f           [512, 128, 1, False, -1]
#  15                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1    296704  ultralytics.nn.modules.block.A2C2f           [384, 256, 1, False, -1]
#  18                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  21        [14, 17, 20]  1    819795  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# YOLOv12s summary: 272 layers, 9,253,523 parameters, 9,253,507 gradients, 21.5 GFLOPs
#
# Transferred 685/691 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 3.11.2 MB/s, size: 25.8 KB)
# train: Scanning C:\Users\alexr\Desktop\CLASE\PARTE1\train\labels.cache... 50 images, 0 backgrounds, 0 corrupt: 100%|██████████| 50/50 [00:00<?, ?it/s]
# val: Fast image access  (ping: 0.10.0 ms, read: 3.51.2 MB/s, size: 28.5 KB)
# c:\Users\alexr\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# val: Scanning C:\Users\alexr\Desktop\CLASE\PARTE1\valid\labels.cache... 21 images, 0 backgrounds, 0 corrupt: 100%|██████████| 21/21 [00:00<?, ?it/s]
# c:\Users\alexr\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Plotting labels to runs\detect\train2\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# Image sizes 416 train, 416 val
# Using 0 dataloader workers
# Logging results to runs\detect\train2
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1         0G      1.294      2.479      1.531         15        416: 100%|██████████| 4/4 [00:13<00:00,  3.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.63s/it]
#                    all         21         42      0.769      0.636      0.708      0.496
#
# 1 epochs completed in 0.005 hours.
# Optimizer stripped from runs\detect\train2\weights\last.pt, 18.9MB
# Optimizer stripped from runs\detect\train2\weights\best.pt, 18.9MB
#
# Validating runs\detect\train2\weights\best.pt...
# Ultralytics 8.3.168  Python-3.10.0 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i9-13900H)
# YOLOv12s summary (fused): 159 layers, 9,231,267 parameters, 0 gradients, 21.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.64s/it]
#                    all         21         42      0.771      0.641       0.71      0.497
# Speed: 0.6ms preprocess, 73.4ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs\detect\train2

# %% [markdown]
# # Run inference on the source

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('runs/detect/train2/weights/best.pt')

# Run inference on 'bus.jpg' with arguments
model.predict(['images/test1.png', 'images/test2.png','images/test3.png'], save=True, imgsz=416, conf=0.30)
result = model.predict(['images/test1.png', 'images/test2.png','images/test3.png'], save=True, imgsz=416, conf=0.30)
# Out:
# 0: 416x416 2 dogs, 58.9ms
# 1: 416x416 1 dog, 58.9ms
# 2: 416x416 1 dog, 58.9ms
# Speed: 1.3ms preprocess, 58.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to runs\detect\predict3
#
# 0: 416x416 2 dogs, 68.9ms
# 1: 416x416 1 dog, 68.9ms
# 2: 416x416 1 dog, 68.9ms
# Speed: 1.1ms preprocess, 68.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to runs\detect\predict3

# %%
# Load a pretrained YOLOv8n model
model = YOLO('runs/detect/train2/weights/best.pt')

# Run inference on 'bus.jpg' with arguments
model.predict('images/video.mp4', save=True, imgsz=416, conf=0.5)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 97.6ms
# video 1/1 (frame 2/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 77.0ms
# video 1/1 (frame 3/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 67.3ms
# video 1/1 (frame 4/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 68.9ms
# video 1/1 (frame 5/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 2 dogs, 77.3ms
# video 1/1 (frame 6/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 75
242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 74.0ms
# video 1/1 (frame 231/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 76.3ms
# video 1/1 (frame 232/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 75.9ms
# video 1/1 (frame 233/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 75.9ms
# video 1/1 (frame 234/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 74.0ms
# video 1/1 (frame 235/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 74.6ms
# video 1/1 (frame 236/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 75.2ms
# video 1/1 (frame 237/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 75.3ms
# video 1/1 (frame 238/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 73.5ms
# video 1/1 (frame 239/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 75.6ms
# video 1/1 (frame 240/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 76.3ms
# video 1/1 (frame 241/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 75.2ms
# video 1/1 (frame 242/242) c:\Users\alexr\Desktop\CLASE\PARTE1\images\video.mp4: 256x416 1 dog, 75.6ms
# Speed: 1.1ms preprocess, 75.3ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to runs\detect\predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 62, 149, 145],
#          [ 62, 149, 145],
#          [ 62, 149, 145],
#          ...,
#          [ 57, 131, 133],
#          [ 56, 130, 132],
#          [ 56, 130, 132]],
#
#         [[ 62, 149, 145],
#          [ 62, 149, 145],
#          [ 62, 149, 145],
#          ...,
#          [ 59, 133, 135],
#          [ 58, 132, 134],
#          [ 58, 132, 134]],
#
#         [[ 62, 149, 145],
#          [ 62, 149, 145],
#          [ 62, 149, 145],
#          ...,
#          [ 62, 135, 140],
#          [ 62, 135, 140],
#          [ 62, 135, 140]],
#
#         ...,
#
#         [[ 54, 138, 118],
#          [ 55, 139, 119],
#          [ 50, 136, 111],
#          ...,
#          [ 24, 115,  99],
#          [ 21, 113,  94],
#          [ 21, 113,  94]],
#
#         [[ 56, 140, 120],
#          [ 55, 139, 119],
#          [ 47, 133, 108],
#          ...,
#          [ 26, 115,  99],
#          [ 23, 114,  98],
#          [ 21, 112,  96]],
#
#         [[ 56, 140, 120],
#          [ 50, 134, 114],
#          [ 43, 129, 104],
#          ...,
#          [ 26, 115,  99],
#          [ 24, 115,  99],
#          [ 23, 114,  98]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 1.1929000029340386, 'inference': 97.60099998675287, 'postprocess': 0.7911999709904194},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 62, 149, 145],
#          [ 62, 149, 145],
#          [ 62, 149, 145],
#          ...,
#          [ 58, 132, 134],
#          [ 57, 131, 133],
#          [ 57, 131, 133]],
#
#         [[ 62, 149, 145],
#          [ 62, 149, 145],
#          [ 62, 149, 145],
#          ...,
#          [ 61, 135, 137],
#          [ 61, 135, 137],
#          [ 59, 133, 135]],
#
#         [[ 62, 149, 145],
#          [ 62, 149, 145],
#          [ 62, 149, 145],
#          ...,
#          [ 64, 136, 143],
#          [ 64, 136, 143],
#          [ 64, 136, 143]],
#
#         ...,
#
#         [[ 54, 143, 127],
#          [ 50, 139, 123],
#          [ 43, 132, 116],
#          ...,
#          [ 34, 111, 104],
#          [ 37, 114, 107],
#          [ 37, 114, 107]],
#
#         [[ 63, 152, 136],
#          [ 56, 145, 129],
#          [ 47, 136, 120],
#          ...,
#          [ 32, 106, 101],
#          [ 37, 111, 106],
#          [ 40, 114, 109]],
#
#         [[ 64, 153, 137],
#          [ 56, 145, 129],
#          [ 49, 138, 122],
#          ...,
#          [ 26, 100,  95],
#          [ 32, 106, 101],
#          [ 37, 111, 106]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 3.0617999145761132, 'inference': 77.0307999337092, 'postprocess': 0.6324000423774123},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 58, 148, 143],
#          [ 58, 148, 143],
#          [ 58, 148, 143],
#          ...,
#          [ 59, 136, 137],
#          [ 57, 134, 135],
#          [ 57, 134, 135]],
#
#         [[ 58, 148, 143],
#          [ 58, 148, 143],
#          [ 58, 148, 143],
#          ...,
#          [ 61, 138, 139],
#          [ 61, 138, 139],
#          [ 60, 137, 138]],
#
#         [[ 58, 148, 143],
#          [ 58, 148, 143],
#          [ 59, 149, 144],
#          ...,
#          [ 63, 138, 144],
#          [ 64, 139, 145],
#          [ 64, 139, 145]],
#
#         ...,
#
#         [[ 42, 123, 104],
#          [ 35, 116,  97],
#          [ 38, 119, 100],
#          ...,
#          [ 27, 103,  98],
#          [ 16,  91,  89],
#          [ 13,  88,  86]],
#
#         [[ 44, 125, 106],
#          [ 42, 123, 104],
#          [ 40, 121, 102],
#          ...,
#          [ 26, 101,  94],
#          [ 18,  91,  89],
#          [ 16,  89,  87]],
#
#         [[ 50, 131, 112],
#          [ 50, 131, 112],
#          [ 41, 122, 103],
#          ...,
#          [ 28, 103,  96],
#          [ 22,  95,  93],
#          [ 18,  91,  89]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 1.0653999634087086, 'inference': 67.2607000451535, 'postprocess': 0.6577000021934509},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 58, 149, 141],
#          [ 58, 149, 141],
#          [ 58, 149, 141],
#          ...,
#          [ 61, 138, 139],
#          [ 59, 136, 137],
#          [ 59, 136, 137]],
#
#         [[ 58, 149, 141],
#          [ 58, 149, 141],
#          [ 58, 149, 141],
#          ...,
#          [ 62, 139, 140],
#          [ 62, 139, 140],
#          [ 62, 139, 140]],
#
#         [[ 58, 149, 141],
#          [ 58, 149, 141],
#          [ 59, 150, 142],
#          ...,
#          [ 64, 139, 145],
#          [ 66, 141, 147],
#          [ 66, 141, 147]],
#
#         ...,
#
#         [[ 21, 110,  89],
#          [ 25, 114,  93],
#          [ 48, 127, 115],
#          ...,
#          [ 24,  95,  86],
#          [ 20,  91,  82],
#          [ 20,  91,  82]],
#
#         [[ 21, 114,  88],
#          [ 25, 118,  92],
#          [ 45, 128, 110],
#          ...,
#          [ 22,  94,  83],
#          [ 18,  90,  79],
#          [ 18,  90,  79]],
#
#         [[ 26, 119,  93],
#          [ 30, 123,  97],
#          [ 43, 126, 108],
#          ...,
#          [ 25,  97,  86],
#          [ 19,  91,  80],
#          [ 19,  91,  80]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 1.0640999535098672, 'inference': 68.94430005922914, 'postprocess': 0.6152000278234482},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 58, 150, 140],
#          [ 58, 150, 140],
#          [ 58, 150, 140],
#          ...,
#          [ 63, 140, 141],
#          [ 63, 140, 141],
#          [ 62, 139, 140]],
#
#         [[ 58, 150, 140],
#          [ 58, 150, 140],
#          [ 58, 150, 140],
#          ...,
#          [ 66, 143, 144],
#          [ 66, 143, 144],
#          [ 64, 141, 142]],
#
#         [[ 58, 150, 140],
#          [ 58, 150, 140],
#          [ 58, 150, 140],
#          ...,
#          [ 67, 142, 148],
#          [ 67, 142, 148],
#          [ 68, 143, 149]],
#
#         ...,
#
#         [[ 40, 133, 107],
#          [ 34, 127, 101],
#          [ 22, 115,  87],
#          ...,
#          [ 56, 150, 133],
#          [ 57, 151, 134],
#          [ 53, 147, 130]],
#
#         [[ 44, 135, 114],
#          [ 37, 128, 107],
#          [ 26, 118,  94],
#          ...,
#          [ 53, 146, 133],
#          [ 56, 149, 136],
#          [ 58, 151, 138]],
#
#         [[ 49, 140, 119],
#          [ 42, 133, 112],
#          [ 27, 119,  95],
#          ...,
#          [ 49, 142, 129],
#          [ 57, 150, 137],
#          [ 68, 161, 148]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 2.975500072352588, 'inference': 77.2883000317961, 'postprocess': 0.6913000252097845},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 58, 150, 140],
#          [ 58, 150, 140],
#          [ 58, 150, 140],
#          ...,
#          [ 63, 140, 141],
#          [ 63, 140, 141],
#          [ 62, 139, 140]],
#
#         [[ 58, 150, 140],
#          [ 58, 150, 140],
#          [ 58, 150, 140],
#          ...,
#          [ 66, 143, 144],
#          [ 66, 143, 144],
#          [ 66, 143, 144]],
#
#         [[ 58, 150, 140],
#          [ 58, 150, 140],
#          [ 58, 150, 140],
#          ...,
#          [ 67, 142, 148],
#          [ 67, 142, 148],
#          [ 68, 143, 149]],
#
#         ...,
#
#         [[ 47, 135, 123],
#          [ 42, 130, 118],
#          [ 49, 137, 125],
#          ...,
#          [ 59, 132, 143],
#          [ 50, 126, 135],
#          [ 43, 119, 128]],
#
#         [[ 37, 125, 113],
#          [ 36, 124, 112],
#          [ 50, 138, 126],
#          ...,
#          [ 46, 124, 121],
#          [ 48, 129, 123],
#          [ 50, 131, 125]],
#
#         [[ 29, 117, 105],
#          [ 30, 118, 106],
#          [ 47, 135, 123],
#          ...,
#          [ 36, 114, 111],
#          [ 40, 121, 115],
#          [ 45, 126, 120]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 2.420600038021803, 'inference': 75.66510001197457, 'postprocess': 0.623099971562624},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 59, 149, 144],
#          [ 59, 149, 144],
#          [ 59, 149, 144],
#          ...,
#          [ 63, 140, 141],
#          [ 63, 140, 141],
#          [ 63, 140, 141]],
#
#         [[ 58, 148, 143],
#          [ 58, 148, 143],
#          [ 58, 148, 143],
#          ...,
#          [ 66, 143, 144],
#          [ 66, 143, 144],
#          [ 66, 143, 144]],
#
#         [[ 58, 149, 141],
#          [ 58, 149, 141],
#          [ 58, 149, 141],
#          ...,
#          [ 67, 142, 148],
#          [ 68, 143, 149],
#          [ 68, 143, 149]],
#
#         ...,
#
#         [[ 38, 125, 111],
#          [ 45, 132, 118],
#          [ 39, 124, 106],
#          ...,
#          [ 27, 116, 102],
#          [ 32, 119, 105],
#          [ 37, 124, 110]],
#
#         [[ 31, 117, 105],
#          [ 46, 132, 120],
#          [ 46, 130, 117],
#          ...,
#          [ 35, 127, 103],
#          [ 31, 121,  97],
#          [ 36, 126, 102]],
#
#         [[ 28, 114, 102],
#          [ 43, 129, 117],
#          [ 47, 131, 118],
#          ...,
#          [ 60, 152, 128],
#          [ 53, 143, 119],
#          [ 49, 139, 115]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 0.8512999629601836, 'inference': 70.30179991852492, 'postprocess': 0.6759000243619084},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 61, 150, 149],
#          [ 61, 150, 149],
#          [ 60, 149, 148],
#          ...,
#          [ 64, 141, 142],
#          [ 63, 140, 141],
#          [ 63, 140, 141]],
#
#         [[ 60, 149, 148],
#          [ 60, 149, 148],
#          [ 59, 148, 147],
#          ...,
#          [ 64, 141, 142],
#          [ 64, 141, 142],
#          [ 64, 141, 142]],
#
#         [[ 56, 146, 141],
#          [ 56, 146, 141],
#          [ 57, 147, 142],
#          ...,
#          [ 67, 143, 147],
#          [ 67, 143, 147],
#          [ 67, 143, 147]],
#
#         ...,
#
#         [[ 35, 126,  98],
#          [ 22, 113,  85],
#          [ 14, 104,  80],
#          ...,
#          [ 42, 134, 110],
#          [ 36, 129, 101],
#          [ 32, 125,  97]],
#
#         [[ 16, 107,  79],
#          [  6,  97,  69],
#          [  7,  97,  73],
#          ...,
#          [ 44, 136, 112],
#          [ 41, 134, 106],
#          [ 35, 128, 100]],
#
#         [[  5,  96,  68],
#          [  2,  93,  65],
#          [ 17, 107,  83],
#          ...,
#          [ 46, 138, 114],
#          [ 44, 137, 109],
#          [ 37, 130, 102]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 0.8460000390186906, 'inference': 67.4755999352783, 'postprocess': 0.6576000014320016},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 66, 151, 154],
#          [ 66, 151, 154],
#          [ 66, 151, 154],
#          ...,
#          [ 63, 140, 141],
#          [ 63, 140, 141],
#          [ 62, 139, 140]],
#
#         [[ 65, 150, 153],
#          [ 65, 150, 153],
#          [ 65, 150, 153],
#          ...,
#          [ 66, 143, 144],
#          [ 66, 143, 144],
#          [ 66, 143, 144]],
#
#         [[ 61, 147, 147],
#          [ 61, 147, 147],
#          [ 61, 147, 147],
#          ...,
#          [ 67, 142, 148],
#          [ 67, 142, 148],
#          [ 68, 143, 149]],
#
#         ...,
#
#         [[ 36, 113, 114],
#          [ 31, 108, 109],
#          [ 28, 104, 108],
#          ...,
#          [ 37, 118, 112],
#          [ 36, 115, 103],
#          [ 37, 116, 104]],
#
#         [[ 36, 113, 112],
#          [ 28, 105, 104],
#          [ 11,  81,  88],
#          ...,
#          [ 31, 115, 108],
#          [ 33, 115, 100],
#          [ 29, 111,  96]],
#
#         [[ 49, 126, 125],
#          [ 36, 113, 112],
#          [ 18,  88,  95],
#          ...,
#          [ 28, 112, 105],
#          [ 32, 114,  99],
#          [ 28, 110,  95]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 0.9139000903815031, 'inference': 70.19310002215207, 'postprocess': 0.6215999601408839},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 63, 148, 151],
#          [ 63, 148, 151],
#          [ 65, 150, 153],
#          ...,
#          [ 62, 139, 140],
#          [ 61, 138, 139],
#          [ 61, 138, 139]],
#
#         [[ 63, 148, 151],
#          [ 63, 148, 151],
#          [ 65, 150, 153],
#          ...,
#          [ 63, 140, 141],
#          [ 63, 140, 141],
#          [ 63, 140, 141]],
#
#         [[ 63, 148, 151],
#          [ 63, 148, 151],
#          [ 63, 148, 151],
#          ...,
#          [ 64, 139, 145],
#          [ 64, 139, 145],
#          [ 64, 139, 145]],
#
#         ...,
#
#         [[ 38, 129, 113],
#          [ 45, 136, 120],
#          [ 41, 127, 115],
#          ...,
#          [ 27, 110,  92],
#          [ 32, 114,  99],
#          [ 34, 116, 101]],
#
#         [[ 38, 129, 113],
#          [ 44, 135, 119],
#          [ 30, 116, 104],
#          ...,
#          [ 34, 115, 104],
#          [ 36, 114, 111],
#          [ 36, 114, 111]],
#
#         [[ 35, 126, 110],
#          [ 27, 118, 102],
#          [ 22, 108,  96],
#          ...,
#          [ 38, 119, 108],
#          [ 36, 114, 111],
#          [ 36, 114, 111]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 1.322000054642558, 'inference': 73.33480007946491, 'postprocess': 0.6713999900966883},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 65, 148, 151],
#          [ 67, 150, 153],
#          [ 67, 150, 153],
#          ...,
#          [ 61, 137, 141],
#          [ 61, 137, 141],
#          [ 60, 136, 140]],
#
#         [[ 64, 147, 150],
#          [ 63, 146, 149],
#          [ 63, 146, 149],
#          ...,
#          [ 63, 139, 143],
#          [ 62, 138, 142],
#          [ 62, 138, 142]],
#
#         [[ 61, 145, 145],
#          [ 60, 144, 144],
#          [ 60, 144, 144],
#          ...,
#          [ 63, 137, 146],
#          [ 63, 137, 146],
#          [ 63, 137, 146]],
#
#         ...,
#
#         [[ 35, 122, 118],
#          [ 32, 119, 115],
#          [ 32, 120, 113],
#          ...,
#          [ 27, 103,  86],
#          [ 20,  93,  77],
#          [ 14,  87,  71]],
#
#         [[ 28, 115, 111],
#          [ 28, 115, 111],
#          [ 32, 117, 113],
#          ...,
#          [ 25, 103,  86],
#          [ 23, 100,  81],
#          [ 11,  88,  69]],
#
#         [[ 23, 110, 106],
#          [ 23, 110, 106],
#          [ 23, 108, 104],
#          ...,
#          [ 25, 103,  86],
#          [ 24, 101,  82],
#          [ 10,  87,  68]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 1.4965999871492386, 'inference': 78.12109997030348, 'postprocess': 0.7093999302014709},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 64, 147, 150],
#          [ 64, 147, 150],
#          [ 65, 148, 151],
#          ...,
#          [ 57, 135, 139],
#          [ 59, 135, 139],
#          [ 59, 135, 139]],
#
#         [[ 64, 147, 150],
#          [ 64, 147, 150],
#          [ 64, 147, 150],
#          ...,
#          [ 59, 137, 141],
#          [ 61, 137, 141],
#          [ 60, 136, 140]],
#
#         [[ 63, 146, 149],
#          [ 63, 146, 149],
#          [ 62, 145, 148],
#          ...,
#          [ 60, 136, 145],
#          [ 61, 135, 144],
#          [ 61, 135, 144]],
#
#         ...,
#
#         [[ 32, 121, 105],
#          [ 25, 114,  98],
#          [ 20, 106,  94],
#          ...,
#          [ 19,  91,  73],
#          [ 20,  87,  70],
#          [ 24,  91,  74]],
#
#         [[ 35, 121, 109],
#          [ 27, 113, 101],
#          [ 24, 103,  97],
#          ...,
#          [ 31, 108,  89],
#          [ 30, 102,  84],
#          [ 26,  98,  80]],
#
#         [[ 35, 121, 109],
#          [ 27, 113, 101],
#          [ 24, 103,  97],
#          ...,
#          [ 39, 116,  97],
#          [ 44, 116,  98],
#          [ 36, 108,  90]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 0.8344000671058893, 'inference': 71.83679996524006, 'postprocess': 0.33139996230602264},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 64, 147, 150],
#          [ 64, 147, 150],
#          [ 64, 147, 150],
#          ...,
#          [ 59, 135, 139],
#          [ 59, 135, 139],
#          [ 59, 135, 139]],
#
#         [[ 64, 147, 150],
#          [ 64, 147, 150],
#          [ 64, 147, 150],
#          ...,
#          [ 61, 137, 141],
#          [ 61, 137, 141],
#          [ 61, 137, 141]],
#
#         [[ 64, 147, 150],
#          [ 64, 147, 150],
#          [ 64, 147, 150],
#          ...,
#          [ 62, 137, 143],
#          [ 62, 137, 143],
#          [ 61, 136, 142]],
#
#         ...,
#
#         [[ 56, 127, 137],
#          [ 44, 115, 125],
#          [ 41, 114, 119],
#          ...,
#          [ 45, 136, 120],
#          [ 47, 138, 122],
#          [ 42, 133, 117]],
#
#         [[ 50, 123, 128],
#          [ 44, 117, 122],
#          [ 45, 119, 119],
#          ...,
#          [ 45, 136, 120],
#          [ 48, 139, 123],
#          [ 51, 142, 126]],
#
#         [[ 50, 123, 128],
#          [ 49, 122, 127],
#          [ 48, 122, 122],
#          ...,
#          [ 42, 133, 117],
#          [ 51, 142, 126],
#          [ 55, 146, 130]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 0.8750000270083547, 'inference': 79.26509995013475, 'postprocess': 0.6951000541448593},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 64, 147, 150],
#          [ 64, 147, 150],
#          [ 64, 147, 150],
#          ...,
#          [ 54, 131, 137],
#          [ 56, 131, 137],
#          [ 55, 130, 136]],
#
#         [[ 64, 147, 150],
#          [ 64, 147, 150],
#          [ 64, 147, 150],
#          ...,
#          [ 55, 132, 138],
#          [ 57, 132, 138],
#          [ 57, 132, 138]],
#
#         [[ 63, 146, 149],
#          [ 63, 146, 149],
#          [ 63, 146, 149],
#          ...,
#          [ 58, 134, 143],
#          [ 59, 133, 142],
#          [ 57, 131, 140]],
#
#         ...,
#
#         [[ 15, 100,  82],
#          [ 24, 109,  91],
#          [ 34, 122, 103],
#          ...,
#          [ 26, 115, 101],
#          [ 28, 117, 103],
#          [ 30, 119, 105]],
#
#         [[ 22, 109,  86],
#          [ 31, 118,  95],
#          [ 35, 125, 101],
#          ...,
#          [ 22, 111,  97],
#          [ 27, 116, 102],
#          [ 29, 118, 104]],
#
#         [[ 29, 116,  93],
#          [ 32, 119,  96],
#          [ 34, 124, 100],
#          ...,
#          [ 22, 111,  97],
#          [ 27, 116, 102],
#          [ 29, 118, 104]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 0.9818999096751213, 'inference': 72.69340008497238, 'postprocess': 0.6336000515148044},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 64, 147, 150],
#          [ 64, 147, 150],
#          [ 64, 147, 150],
#          ...,
#          [ 53, 130, 136],
#          [ 53, 130, 136],
#          [ 53, 130, 136]],
#
#         [[ 63, 146, 149],
#          [ 63, 146, 149],
#          [ 63, 146, 149],
#          ...,
#          [ 55, 132, 138],
#          [ 55, 132, 138],
#          [ 55, 132, 138]],
#
#         [[ 63, 147, 147],
#          [ 63, 147, 147],
#          [ 63, 147, 147],
#          ...,
#          [ 55, 131, 140],
#          [ 57, 133, 142],
#          [ 58, 134, 143]],
#
#         ...,
#
#         [[ 31, 115, 108],
#          [ 43, 127, 120],
#          [ 45, 133, 126],
#          ...,
#          [ 60, 136, 145],
#          [ 65, 141, 150],
#          [ 53, 129, 138]],
#
#         [[ 37, 121, 114],
# ...
#
#         [[ 28, 112,  83],
#          [ 21, 105,  76],
#          [ 14,  96,  67],
#          ...,
#          [ 35, 120, 116],
#          [ 40, 125, 121],
#          [ 41, 126, 122]],
#
#         [[ 25, 113,  81],
#          [ 19, 107,  75],
#          [ 15, 100,  69],
#          ...,
#          [ 30, 118, 106],
#          [ 37, 125, 113],
#          [ 40, 128, 116]],
#
#         [[ 29, 117,  85],
#          [ 20, 108,  76],
#          [ 19, 104,  73],
#          ...,
#          [ 22, 110,  98],
#          [ 30, 118, 106],
#          [ 37, 125, 113]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 1.0763999307528138, 'inference': 75.87160007096827, 'postprocess': 0.48070005141198635},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 61, 144, 147],
#          [ 61, 144, 147],
#          [ 61, 144, 147],
#          ...,
#          [ 50, 149, 133],
#          [ 50, 149, 133],
#          [ 50, 149, 133]],
#
#         [[ 63, 146, 149],
#          [ 63, 146, 149],
#          [ 63, 146, 149],
#          ...,
#          [ 50, 149, 133],
#          [ 50, 149, 133],
#          [ 50, 149, 133]],
#
#         [[ 64, 143, 151],
#          [ 64, 143, 151],
#          [ 65, 144, 152],
#          ...,
#          [ 49, 148, 132],
#          [ 49, 148, 132],
#          [ 49, 148, 132]],
#
#         ...,
#
#         [[ 60, 145, 127],
#          [ 57, 142, 124],
#          [ 48, 138, 119],
#          ...,
#          [ 41, 139, 117],
#          [ 41, 139, 117],
#          [ 41, 139, 117]],
#
#         [[ 53, 138, 120],
#          [ 51, 136, 118],
#          [ 45, 132, 116],
#          ...,
#          [ 42, 140, 118],
#          [ 41, 139, 117],
#          [ 40, 138, 116]],
#
#         [[ 51, 136, 118],
#          [ 48, 133, 115],
#          [ 44, 131, 115],
#          ...,
#          [ 43, 141, 119],
#          [ 42, 140, 118],
#          [ 41, 139, 117]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 1.0500999633222818, 'inference': 75.85149991791695, 'postprocess': 0.7091000443324447},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 62, 143, 146],
#          [ 62, 143, 146],
#          [ 62, 143, 146],
#          ...,
#          [ 50, 149, 133],
#          [ 50, 149, 133],
#          [ 50, 149, 133]],
#
#         [[ 64, 145, 148],
#          [ 64, 145, 148],
#          [ 64, 145, 148],
#          ...,
#          [ 50, 149, 133],
#          [ 50, 149, 133],
#          [ 50, 149, 133]],
#
#         [[ 65, 141, 150],
#          [ 65, 141, 150],
#          [ 66, 142, 151],
#          ...,
#          [ 48, 147, 131],
#          [ 48, 147, 131],
#          [ 48, 147, 131]],
#
#         ...,
#
#         [[ 28, 125, 105],
#          [ 35, 132, 112],
#          [ 37, 134, 114],
#          ...,
#          [ 26, 114, 107],
#          [ 29, 113, 106],
#          [ 29, 113, 106]],
#
#         [[ 26, 123, 103],
#          [ 33, 130, 110],
#          [ 37, 134, 114],
#          ...,
#          [ 20, 106,  99],
#          [ 28, 104,  99],
#          [ 28, 104,  99]],
#
#         [[ 26, 123, 103],
#          [ 33, 130, 110],
#          [ 37, 134, 114],
#          ...,
#          [ 20, 106,  99],
#          [ 26, 102,  97],
#          [ 26, 102,  97]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 1.1159999994561076, 'inference': 74.04360000509769, 'postprocess': 0.7207000162452459},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 62, 143, 146],
#          [ 62, 143, 146],
#          [ 62, 143, 146],
#          ...,
#          [ 47, 146, 130],
#          [ 46, 145, 129],
#          [ 46, 145, 129]],
#
#         [[ 64, 145, 148],
#          [ 64, 145, 148],
#          [ 64, 145, 148],
#          ...,
#          [ 46, 145, 129],
#          [ 45, 144, 128],
#          [ 45, 144, 128]],
#
#         [[ 65, 141, 150],
#          [ 65, 141, 150],
#          [ 65, 141, 150],
#          ...,
#          [ 43, 142, 126],
#          [ 42, 141, 125],
#          [ 42, 141, 125]],
#
#         ...,
#
#         [[ 21, 121, 112],
#          [ 16, 116, 107],
#          [ 19, 115, 111],
#          ...,
#          [ 59, 133, 135],
#          [ 48, 125, 124],
#          [ 42, 119, 118]],
#
#         [[ 22, 120, 118],
#          [ 17, 115, 113],
#          [ 22, 118, 116],
#          ...,
#          [ 71, 136, 144],
#          [ 59, 130, 135],
#          [ 53, 124, 129]],
#
#         [[ 22, 120, 118],
#          [ 17, 115, 113],
#          [ 22, 118, 116],
#          ...,
#          [ 72, 137, 145],
#          [ 63, 134, 139],
#          [ 59, 130, 135]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 0.9610999841243029, 'inference': 74.59960004780442, 'postprocess': 0.7225999142974615},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 66, 147, 150],
#          [ 66, 147, 150],
#          [ 65, 146, 149],
#          ...,
#          [ 46, 145, 129],
#          [ 46, 145, 129],
#          [ 46, 145, 129]],
#
#         [[ 67, 148, 151],
#          [ 67, 148, 151],
#          [ 66, 147, 150],
#          ...,
#          [ 45, 144, 128],
#          [ 45, 144, 128],
#          [ 45, 144, 128]],
#
#         [[ 66, 142, 151],
#          [ 66, 142, 151],
#          [ 66, 142, 151],
#          ...,
#          [ 42, 141, 125],
#          [ 42, 141, 125],
#          [ 42, 141, 125]],
#
#         ...,
#
#         [[ 52, 129, 115],
#          [ 53, 130, 116],
#          [ 38, 120, 105],
#          ...,
#          [ 44, 134, 115],
#          [ 37, 129, 105],
#          [ 28, 120,  96]],
#
#         [[ 52, 129, 115],
#          [ 49, 126, 112],
#          [ 27, 109,  94],
#          ...,
#          [ 45, 142, 117],
#          [ 40, 138, 109],
#          [ 33, 131, 102]],
#
#         [[ 51, 128, 114],
#          [ 45, 122, 108],
#          [ 25, 107,  92],
#          ...,
#          [ 49, 146, 121],
#          [ 45, 143, 114],
#          [ 40, 138, 109]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 1.1956000234931707, 'inference': 75.237299897708, 'postprocess': 0.6362000713124871},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 65, 144, 152],
#          [ 65, 144, 152],
#          [ 65, 144, 152],
#          ...,
#          [ 43, 142, 126],
#          [ 43, 142, 126],
#          [ 43, 142, 126]],
#
#         [[ 66, 145, 153],
#          [ 66, 145, 153],
#          [ 66, 145, 153],
#          ...,
#          [ 41, 140, 124],
#          [ 41, 140, 124],
#          [ 41, 140, 124]],
#
#         [[ 65, 140, 153],
#          [ 65, 140, 153],
#          [ 65, 140, 153],
#          ...,
#          [ 44, 137, 124],
#          [ 44, 137, 124],
#          [ 44, 137, 124]],
#
#         ...,
#
#         [[ 30, 110,  93],
#          [ 29, 109,  92],
#          [ 26, 112,  85],
#          ...,
#          [ 54, 138, 123],
#          [ 44, 132, 113],
#          [ 45, 133, 114]],
#
#         [[ 20, 103,  79],
#          [ 19, 102,  78],
#          [ 17, 105,  73],
#          ...,
#          [ 61, 141, 138],
#          [ 46, 130, 123],
#          [ 42, 126, 119]],
#
#         [[ 14,  97,  73],
#          [ 14,  97,  73],
#          [ 16, 104,  72],
#          ...,
#          [ 67, 147, 144],
#          [ 52, 136, 129],
#          [ 44, 128, 121]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 1.1412999592721462, 'inference': 75.31790004577488, 'postprocess': 0.6497000576928258},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 65, 143, 155],
#          [ 65, 143, 155],
#          [ 65, 143, 155],
#          ...,
#          [ 43, 139, 124],
#          [ 43, 139, 124],
#          [ 43, 139, 124]],
#
#         [[ 66, 144, 156],
#          [ 66, 144, 156],
#          [ 66, 144, 156],
#          ...,
#          [ 41, 137, 122],
#          [ 41, 137, 122],
#          [ 41, 137, 122]],
#
#         [[ 65, 139, 155],
#          [ 65, 139, 155],
#          [ 65, 139, 155],
#          ...,
#          [ 43, 136, 123],
#          [ 43, 136, 123],
#          [ 43, 136, 123]],
#
#         ...,
#
#         [[ 48, 124, 107],
#          [ 41, 117, 100],
#          [ 39, 114, 100],
#          ...,
#          [ 66, 137, 147],
#          [ 57, 128, 138],
#          [ 51, 122, 132]],
#
#         [[ 44, 119, 105],
#          [ 41, 116, 102],
#          [ 40, 114, 104],
#          ...,
#          [ 72, 143, 153],
#          [ 61, 132, 142],
#          [ 55, 126, 136]],
#
#         [[ 44, 119, 105],
#          [ 46, 121, 107],
#          [ 46, 120, 110],
#          ...,
#          [ 77, 148, 158],
#          [ 66, 137, 147],
#          [ 57, 128, 138]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 1.1172000085934997, 'inference': 73.4647000208497, 'postprocess': 0.7305999752134085},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 65, 143, 155],
#          [ 65, 143, 155],
#          [ 65, 143, 155],
#          ...,
#          [ 42, 135, 122],
#          [ 42, 135, 122],
#          [ 42, 135, 122]],
#
#         [[ 63, 141, 153],
#          [ 63, 141, 153],
#          [ 63, 141, 153],
#          ...,
#          [ 43, 136, 123],
#          [ 43, 136, 123],
#          [ 43, 136, 123]],
#
#         [[ 61, 135, 151],
#          [ 61, 135, 151],
#          [ 61, 135, 151],
#          ...,
#          [ 47, 136, 127],
#          [ 47, 136, 127],
#          [ 47, 136, 127]],
#
#         ...,
#
#         [[ 17, 110,  89],
#          [ 19, 112,  91],
#          [ 33, 126, 105],
#          ...,
#          [ 29, 126, 106],
#          [ 23, 122,  97],
#          [ 20, 119,  94]],
#
#         [[ 17, 110,  89],
#          [ 28, 121, 100],
#          [ 42, 135, 114],
#          ...,
#          [ 26, 122, 105],
#          [ 20, 117,  97],
#          [ 17, 114,  94]],
#
#         [[ 26, 119,  98],
#          [ 38, 131, 110],
#          [ 42, 135, 114],
#          ...,
#          [ 24, 120, 103],
#          [ 20, 117,  97],
#          [ 17, 114,  94]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 1.1037999065592885, 'inference': 75.55359997786582, 'postprocess': 0.7340000011026859},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 61, 133, 149],
#          [ 61, 133, 149],
#          [ 61, 133, 149],
#          ...,
#          [ 47, 134, 125],
#          [ 47, 134, 125],
#          [ 47, 134, 125]],
#
#         [[ 60, 132, 148],
#          [ 60, 132, 148],
#          [ 60, 132, 148],
#          ...,
#          [ 47, 134, 125],
#          [ 47, 134, 125],
#          [ 47, 134, 125]],
#
#         [[ 61, 130, 147],
#          [ 61, 130, 147],
#          [ 62, 131, 148],
#          ...,
#          [ 47, 134, 125],
#          [ 47, 134, 125],
#          [ 47, 134, 125]],
#
#         ...,
#
#         [[ 42, 124, 124],
#          [ 45, 127, 127],
#          [ 51, 128, 134],
#          ...,
#          [ 28, 117,  96],
#          [ 33, 117, 102],
#          [ 38, 122, 107]],
#
#         [[ 47, 126, 125],
#          [ 53, 132, 131],
#          [ 46, 123, 124],
#          ...,
#          [ 25, 113,  94],
#          [ 32, 116, 101],
#          [ 37, 121, 106]],
#
#         [[ 48, 127, 126],
#          [ 44, 123, 122],
#          [ 31, 108, 109],
#          ...,
#          [ 25, 113,  94],
#          [ 31, 115, 100],
#          [ 36, 120, 105]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 0.9791000047698617, 'inference': 76.3335000956431, 'postprocess': 0.763899995945394},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 56, 128, 144],
#          [ 56, 128, 144],
#          [ 57, 129, 145],
#          ...,
#          [ 43, 131, 119],
#          [ 43, 131, 119],
#          [ 43, 131, 119]],
#
#         [[ 57, 129, 145],
#          [ 57, 129, 145],
#          [ 59, 131, 147],
#          ...,
#          [ 42, 130, 118],
#          [ 42, 130, 118],
#          [ 42, 130, 118]],
#
#         [[ 61, 130, 147],
#          [ 61, 130, 147],
#          [ 62, 131, 148],
#          ...,
#          [ 40, 131, 117],
#          [ 40, 131, 117],
#          [ 40, 131, 117]],
#
#         ...,
#
#         [[ 22,  86,  97],
#          [ 35,  99, 110],
#          [ 50, 120, 127],
#          ...,
#          [ 23, 128,  98],
#          [ 21, 128,  98],
#          [ 22, 129,  99]],
#
#         [[ 15,  79,  90],
#          [ 28,  92, 103],
#          [ 44, 114, 121],
#          ...,
#          [ 23, 131,  98],
#          [ 22, 129,  99],
#          [ 22, 129,  99]],
#
#         [[ 12,  76,  87],
#          [ 25,  89, 100],
#          [ 40, 110, 117],
#          ...,
#          [ 24, 132,  99],
#          [ 22, 129,  99],
#          [ 22, 129,  99]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 1.070600003004074, 'inference': 75.22450003307313, 'postprocess': 0.6566999945789576},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog'}
#  obb: None
#  orig_img: array([[[ 61, 130, 147],
#          [ 61, 130, 147],
#          [ 62, 131, 148],
#          ...,
#          [ 41, 132, 118],
#          [ 41, 132, 118],
#          [ 41, 132, 118]],
#
#         [[ 61, 130, 147],
#          [ 61, 130, 147],
#          [ 62, 131, 148],
#          ...,
#          [ 44, 135, 121],
#          [ 44, 135, 121],
#          [ 44, 135, 121]],
#
#         [[ 59, 133, 149],
#          [ 59, 133, 149],
#          [ 59, 133, 149],
#          ...,
#          [ 42, 136, 119],
#          [ 42, 136, 119],
#          [ 42, 136, 119]],
#
#         ...,
#
#         [[ 28,  96, 108],
#          [ 26,  94, 106],
#          [ 31, 103, 105],
#          ...,
#          [ 15, 115,  94],
#          [ 18, 117, 101],
#          [ 17, 116, 100]],
#
#         [[ 14,  86,  86],
#          [ 16,  88,  88],
#          [ 29, 105,  95],
#          ...,
#          [ 19, 118, 102],
#          [ 18, 115, 104],
#          [ 15, 112, 101]],
#
#         [[  9,  81,  81],
#          [ 13,  85,  85],
#          [ 30, 106,  96],
#          ...,
#          [ 22, 121, 105],
#          [ 15, 112, 101],
#          [ 12, 109,  98]]], shape=(432, 768, 3), dtype=uint8)
#  orig_shape: (432, 768)
#  path: 'c:\\Users\\alexr\\Desktop\\CLASE\\PARTE1\\images\\video.mp4'
#  probs: None
#  save_dir: 'runs\\detect\\predict2'
#  speed: {'preprocess': 1.179100014269352, 'inference': 75.5901999073103, 'postprocess': 0.6703999824821949}]
